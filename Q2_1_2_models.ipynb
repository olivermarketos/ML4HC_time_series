# %% [markdown]
# # Classifiers

# %%
# Core Libraries
import os
import glob
import itertools

# Data Handling
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# Progress Bar
from tqdm import tqdm

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import export_graphviz
from IPython.display import Image
from sklearn.metrics import ConfusionMatrixDisplay, roc_curve, auc

# Statistics
from scipy.stats import skew, kurtosis, randint

# Modeling
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    average_precision_score,
    recall_score,
    confusion_matrix,
    roc_auc_score,
)
from sklearn.linear_model import LogisticRegression

# %%
df_a =pd.read_parquet('data/set_a_for_q2_1_more_feat.parquet', engine='pyarrow')
df_b =pd.read_parquet('data/set_b_for_q2_1_more_feat.parquet', engine='pyarrow')
df_c =pd.read_parquet('data/set_c_for_q2_1_more_feat.parquet', engine='pyarrow')

# %%
df_a
# Out:
#       TroponinI_mean  TroponinI_std  TroponinI_max  TroponinI_min
# 0           2.133333       0.919239            2.7            1.6  \
# 1           2.133333       0.919239            2.7            1.6
# 2           2.133333       0.919239            2.7            1.6
# 3           2.133333       0.919239            2.7            1.6
# 4           2.133333       0.919239            2.7            1.6
# ...              ...            ...            ...            ...
# 3995        2.133333       0.919239            2.7            1.6
# 3996        2.133333       0.919239            2.7            1.6
# 3997        2.133333       0.919239            2.7            1.6
# 3998        2.133333       0.919239            2.7            1.6
# 3999        2.133333       0.919239            2.7            1.6
#
#       TroponinI_skew  DiasABP_mean  DiasABP_std  DiasABP_max  DiasABP_min
# 0           0.266782     58.847518     7.080782         77.0         46.0  \
# 1           0.266782     58.448148     5.205690         75.0         46.0
# 2           0.266782     67.666667     8.372290         81.0         52.0
# 3           0.266782     58.847518     7.080782         77.0         46.0
# 4           0.266782     58.847518     7.080782         77.0         46.0
# ...              ...           ...          ...          ...          ...
# 3995        0.266782     69.187943     6.671703         82.0         47.5
# 3996        0.266782     58.847518     7.080782         77.0         46.0
# 3997        0.266782     72.125000     8.759519         84.5         65.0
# 3998        0.266782     94.383721     7.610955        108.0         67.5
# 3999        0.266782     55.125758     7.198532         80.0         44.0
#
#       DiasABP_skew  ...  Weight_VAR_mean  Weight_VAR_std  Weight_VAR_max
# 0         0.389305  ...        80.121087    9.094970e-02            81.0  \
# 1         0.285246  ...        80.680000    9.820457e-01            81.6
# 2        -0.079364  ...        56.700000    1.036433e-15            56.7
# 3         0.389305  ...        84.600000    0.000000e+00            84.6
# 4         0.389305  ...        80.121087    9.094970e-02            81.0
# ...            ...  ...              ...             ...             ...
# 3995     -0.489340  ...        87.000000    9.094970e-02            87.0
# 3996      0.389305  ...       166.400000    0.000000e+00           166.4
# 3997      1.387467  ...       109.000000    0.000000e+00           109.0
# 3998     -1.156631  ...        87.400000    0.000000e+00            87.4
# 3999      1.461892  ...        87.762069    3.350737e+00            88.8
#
#       Weight_VAR_min  Weight_VAR_skew  RecordID_first  Age_first
# 0              78.15         0.000000        132539.0       54.0  \
# 1              76.00        -3.786403        132540.0       76.0
# 2              56.70         0.000000        132541.0       44.0
# 3              84.60         0.000000        132543.0       68.0
# 4              78.15         0.000000        132545.0       88.0
# ...              ...              ...             ...        ...
# 3995           87.00         0.000000        142665.0       70.0
# 3996          166.40         0.000000        142667.0       25.0
# 3997          109.00         0.000000        142670.0       44.0
# 3998           87.40         0.000000        142671.0       37.0
# 3999           70.70        -5.042661        142673.0       78.0
#
#       Gender_first  Height_first  Weight_first
# 0              0.0         170.2          78.6
# 1              1.0         175.3          76.0
# 2              0.0         170.2          56.7
# 3              1.0         180.3          84.6
# 4              0.0         170.2          78.6
# ...            ...           ...           ...
# 3995           0.0         170.2          87.0
# 3996           1.0         170.2         166.4
# 3997           1.0         170.2         109.0
# 3998           1.0         170.2          87.4
# 3999           0.0         157.5          70.7
#
# [4000 rows x 189 columns]

# %%
static_variables = ['RecordID', 'Age', 'Gender', 'Height', 'ICUType', 'Weight']

if 'ICUType' not in df_a.columns: static_variables.remove('ICUType')

static_variables_we_want = ['Age', 'Gender', 'Height', 'Weight']
all_variables = ['Weight', 'Age', 'TroponinI', 'DiasABP', 'MechVent', 'HCO3', 'Cholesterol', 'HCT', 'SaO2', 'WBC', 'SysABP', 'Urine', 'ICUType', 'Gender', 'ALP', 'Creatinine', 'K', 'AST', 'Glucose', 'RespRate', 'MAP', 'FiO2', 'BUN', 'Na', 'Bilirubin', 'TroponinT', 'PaCO2', 'Height', 'GCS', 'HR', 'pH', 'PaO2', 'Lactate', 'ALT', 'NISysABP', 'RecordID', 'Platelets', 'Temp', 'Mg', 'NIDiasABP', 'Albumin', 'NIMAP']
dyn_variables = [x for x in all_variables if x not in static_variables]
dyn_variables.append('Weight_VAR')
len(dyn_variables), len(static_variables_we_want)
# Out:
# (38, 4)

# %%
assert df_a.isnull().sum().sum() == 0
assert df_b.isnull().sum().sum() == 0
assert df_c.isnull().sum().sum() == 0

# %%
df_a['RecordID_first']
# Out:
# 0       132539.0
# 1       132540.0
# 2       132541.0
# 3       132543.0
# 4       132545.0
#           ...
# 3995    142665.0
# 3996    142667.0
# 3997    142670.0
# 3998    142671.0
# 3999    142673.0
# Name: RecordID_first, Length: 4000, dtype: float64

# %%
outcomes = pd.read_csv('data/outcomes.csv')

outcomes_a = outcomes.loc[outcomes['RecordID'].isin(df_a['RecordID_first'])]
outcomes_b = outcomes.loc[outcomes['RecordID'].isin(df_b['RecordID_first'])]
outcomes_c = outcomes.loc[outcomes['RecordID'].isin(df_c['RecordID_first'])]

# %% [markdown]
# ## Random forest

# %% [markdown]
# Random search is surprisingly efficient compared to grid search. Although grid search will find the optimal value of hyperparameters (assuming they are in your grid) eventually, random search will usually find a "close-enough" value in far fewer iterations.

# %%
# --- Utility Functions ---
def evaluate_model(model, X, y_true, title_info=None):
    y_pred = model.predict(X)
    y_proba = model.predict_proba(X)[:, 1]
    
    cm = confusion_matrix(y_true, y_pred)
    ConfusionMatrixDisplay(cm, display_labels=[0, 1]).plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix, " + (title_info if title_info else ""))
    plt.show()

    roc_auc = roc_auc_score(y_true, y_proba)
    avg_precision = average_precision_score(y_true, y_proba)
    
    print(f"ROC AUC Score: {roc_auc:.4f}")
    print(f"Average Precision Score: {avg_precision:.4f}")
    return roc_auc, avg_precision

def train_rf(X_train, y_train, **kwargs):
    rf = RandomForestClassifier(random_state=42, **kwargs)
    rf.fit(X_train, y_train)
    return rf

# %%
# --- Run a Few Models with Varying Parameters ---
feature_cols = [col for col in df_a.columns if col != 'RecordID_first']

# Model 1
rf1 = train_rf(df_a[feature_cols], outcomes_a['In-hospital_death'],
               n_estimators=100, max_depth=10, class_weight='balanced')
evaluate_model(rf1, df_c[feature_cols], outcomes_c['In-hospital_death'], title_info =' 100 Trees, Depth 10, Balanced')

# Model 2
rf2 = train_rf(df_a[feature_cols], outcomes_a['In-hospital_death'],
               n_estimators=1000, max_depth=10, class_weight='balanced')
evaluate_model(rf2, df_c[feature_cols], outcomes_c['In-hospital_death'], title_info =' 1000 Trees, Depth 10, Balanced')

# Model 3
rf3 = train_rf(df_a[feature_cols], outcomes_a['In-hospital_death'],
               n_estimators=1000, max_depth=15, class_weight='balanced')
evaluate_model(rf3, df_c[feature_cols], outcomes_c['In-hospital_death'], title_info =' 1000 Trees, Depth 15, Balanced')

# Model 4
rf4 = train_rf(df_a[feature_cols], outcomes_a['In-hospital_death'],
               n_estimators=1000, max_depth=15, class_weight=None)
evaluate_model(rf4, df_c[feature_cols], outcomes_c['In-hospital_death'], title_info =' 1000 Trees, Depth 15, No Class Weight')
# Out:
# ROC AUC Score: 0.8344
# Average Precision Score: 0.4438
# ROC AUC Score: 0.8390
# Average Precision Score: 0.4569
# ROC AUC Score: 0.8384
# Average Precision Score: 0.4473
# ROC AUC Score: 0.8183
# Average Precision Score: 0.4936
# (0.8183389020285068, 0.49361632292699675)

# %%
# --- Randomized Hyperparameter Search ---
param_dist = {
    'n_estimators': randint(100, 1000),
    'max_depth': randint(10, 20),
    'max_samples': [0.5, 0.75, 1.0],
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 5), #limit complexity by limiting nb leaf in tree
    'class_weight': ['balanced', None],
    'max_features': ['sqrt', 'log2', None]
}

random_search = RandomizedSearchCV(
    RandomForestClassifier(random_state=42),
    param_distributions=param_dist,
    n_iter=30,  
    cv =3,
    verbose=1,
    n_jobs=-1
)

random_search.fit(df_a[feature_cols], outcomes_a['In-hospital_death'])

print("\nBest parameters from random search:")
print(random_search.best_estimator_)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
#
# Best parameters from random search:
# RandomForestClassifier(class_weight='balanced', max_depth=18, max_samples=1.0,
#                        min_samples_leaf=4, min_samples_split=9,
#                        n_estimators=712, random_state=42)

# %%
# --- Evaluate Best Model ---
best_rf = random_search.best_estimator_
evaluate_model(best_rf, df_c[feature_cols], outcomes_c['In-hospital_death'], title_info=f'Best Model from Random Search : {random_search.best_estimator_}')
# Out:
# ROC AUC Score: 0.8431
# Average Precision Score: 0.4789
# (0.8431379910150043, 0.47894561728302)

# %% [markdown]
# #### Compute feature importance

# %%
#  compute feature importance
importances = best_rf.feature_importances_
indices = np.argsort(importances)[::-1]
# Print the feature ranking
print("Feature ranking:")
for f in range(len(feature_cols)):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]), df_a.columns[indices[f]])
# Plot the feature importances of the forest
plt.figure(figsize=(10, 10))
plt.title("Feature importances")
plt.bar(range(len(feature_cols)), importances[indices], align="center")
plt.xticks(range(len(feature_cols)), indices)
plt.xlim([-1, len(feature_cols)])
plt.show()
# Out:
# Feature ranking:
# 1. feature 114 (0.044213) GCS_mean
# 2. feature 44 (0.033253) Urine_mean
# 3. feature 116 (0.028190) GCS_max
# 4. feature 92 (0.025208) BUN_min
# 5. feature 89 (0.024895) BUN_mean
# 6. feature 45 (0.021962) Urine_std
# 7. feature 91 (0.021812) BUN_max
# 8. feature 46 (0.014876) Urine_max
# 9. feature 184 (0.014347) RecordID_first
# 10. feature 115 (0.013299) GCS_std
# 11. feature 109 (0.012686) PaCO2_mean
# 12. feature 118 (0.012000) GCS_skew
# 13. feature 154 (0.010966) Temp_mean
# 14. feature 15 (0.010739) HCO3_mean
# 15. feature 54 (0.010265) Creatinine_mean
# 16. feature 57 (0.010207) Creatinine_min
# 17. feature 69 (0.009411) Glucose_mean
# 18. feature 137 (0.008481) Lactate_min
# 19. feature 56 (0.008015) Creatinine_max
# 20. feature 71 (0.007963) Glucose_max
# 21. feature 121 (0.007923) HR_max
# 22. feature 18 (0.007912) HCO3_min
# 23. feature 181 (0.007322) Weight_VAR_max
# 24. feature 179 (0.007255) Weight_VAR_mean
# 25. feature 182 (0.007111) Weight_VAR_min
# 26. feature 129 (0.007080) PaO2_mean
# 27. feature 48 (0.006946) Urine_skew
# 28. feature 119 (0.006931) HR_mean
# 29. feature 155 (0.006904) Temp_std
# 30. feature 37 (0.006896) WBC_min
# 31. feature 130 (0.006824) PaO2_std
# 32. feature 144 (0.006764) NISysABP_mean
# 33. feature 34 (0.006676) WBC_mean
# 34. feature 120 (0.006675) HR_std
# 35. feature 88 (0.006665) FiO2_skew
# 36. feature 149 (0.006643) Platelets_mean
# 37. feature 112 (0.006584) PaCO2_min
# 38. feature 36 (0.006519) WBC_max
# 39. feature 123 (0.006441) HR_skew
# 40. feature 70 (0.006394) Glucose_std
# 41. feature 151 (0.006394) Platelets_max
# 42. feature 147 (0.006305) NISysABP_min
# 43. feature 152 (0.006277) Platelets_min
# 44. feature 150 (0.006263) Platelets_std
# 45. feature 134 (0.006159) Lactate_mean
# 46. feature 84 (0.006100) FiO2_mean
# 47. feature 49 (0.006044) ALP_mean
# 48. feature 187 (0.006025) Height_first
# 49. feature 124 (0.005969) pH_mean
# 50. feature 158 (0.005951) Temp_skew
# 51. feature 59 (0.005949) K_mean
# 52. feature 174 (0.005937) NIMAP_mean
# 53. feature 94 (0.005841) Na_mean
# 54. feature 132 (0.005827) PaO2_min
# 55. feature 156 (0.005730) Temp_max
# 56. feature 164 (0.005723) NIDiasABP_mean
# 57. feature 90 (0.005641) BUN_std
# 58. feature 157 (0.005627) Temp_min
# 59. feature 111 (0.005547) PaCO2_max
# 60. feature 175 (0.005532) NIMAP_std
# 61. feature 168 (0.005519) NIDiasABP_skew
# 62. feature 72 (0.005439) Glucose_min
# 63. feature 85 (0.005438) FiO2_std
# 64. feature 177 (0.005413) NIMAP_min
# 65. feature 131 (0.005368) PaO2_max
# 66. feature 51 (0.005347) ALP_max
# 67. feature 122 (0.005341) HR_min
# 68. feature 125 (0.005331) pH_std
# 69. feature 27 (0.005301) HCT_min
# 70. feature 167 (0.005283) NIDiasABP_min
# 71. feature 99 (0.005271) Bilirubin_mean
# 72. feature 42 (0.005254) SysABP_min
# 73. feature 117 (0.005206) GCS_min
# 74. feature 17 (0.005191) HCO3_max
# 75. feature 24 (0.005125) HCT_mean
# 76. feature 39 (0.005032) SysABP_mean
# 77. feature 169 (0.004973) Albumin_mean
# 78. feature 25 (0.004959) HCT_std
# 79. feature 52 (0.004955) ALP_min
# 80. feature 145 (0.004931) NISysABP_std
# 81. feature 160 (0.004895) Mg_std
# 82. feature 127 (0.004894) pH_min
# 83. feature 35 (0.004872) WBC_std
# 84. feature 101 (0.004871) Bilirubin_max
# 85. feature 110 (0.004855) PaCO2_std
# 86. feature 26 (0.004777) HCT_max
# 87. feature 148 (0.004710) NISysABP_skew
# 88. feature 180 (0.004701) Weight_VAR_std
# 89. feature 136 (0.004676) Lactate_max
# 90. feature 60 (0.004666) K_std
# 91. feature 165 (0.004639) NIDiasABP_std
# 92. feature 55 (0.004593) Creatinine_std
# 93. feature 62 (0.004589) K_min
# 94. feature 128 (0.004566) pH_skew
# 95. feature 146 (0.004550) NISysABP_max
# 96. feature 172 (0.004493) Albumin_min
# 97. feature 38 (0.004450) WBC_skew
# 98. feature 159 (0.004412) Mg_mean
# 99. feature 178 (0.004355) NIMAP_skew
# 100. feature 16 (0.004344) HCO3_std
# 101. feature 153 (0.004337) Platelets_skew
# 102. feature 96 (0.004332) Na_max
# 103. feature 73 (0.004300) Glucose_skew
# 104. feature 9 (0.004297) DiasABP_skew
# 105. feature 41 (0.004294) SysABP_max
# 106. feature 102 (0.004281) Bilirubin_min
# 107. feature 28 (0.004278) HCT_skew
# 108. feature 63 (0.004266) K_skew
# 109. feature 176 (0.004252) NIMAP_max
# 110. feature 166 (0.004232) NIDiasABP_max
# 111. feature 19 (0.004111) HCO3_skew
# 112. feature 6 (0.004088) DiasABP_std
# 113. feature 171 (0.004064) Albumin_max
# 114. feature 93 (0.004021) BUN_skew
# 115. feature 95 (0.003957) Na_std
# 116. feature 97 (0.003947) Na_min
# 117. feature 43 (0.003908) SysABP_skew
# 118. feature 126 (0.003862) pH_max
# 119. feature 61 (0.003752) K_max
# 120. feature 133 (0.003710) PaO2_skew
# 121. feature 75 (0.003703) RespRate_std
# 122. feature 113 (0.003604) PaCO2_skew
# 123. feature 78 (0.003584) RespRate_skew
# 124. feature 163 (0.003509) Mg_skew
# 125. feature 40 (0.003491) SysABP_std
# 126. feature 80 (0.003478) MAP_std
# 127. feature 79 (0.003457) MAP_mean
# 128. feature 7 (0.003425) DiasABP_max
# 129. feature 8 (0.003399) DiasABP_min
# 130. feature 74 (0.003378) RespRate_mean
# 131. feature 82 (0.003362) MAP_min
# 132. feature 83 (0.003339) MAP_skew
# 133. feature 5 (0.003330) DiasABP_mean
# 134. feature 66 (0.003236) AST_max
# 135. feature 81 (0.003148) MAP_max
# 136. feature 58 (0.003107) Creatinine_skew
# 137. feature 161 (0.003101) Mg_max
# 138. feature 135 (0.003000) Lactate_std
# 139. feature 162 (0.002883) Mg_min
# 140. feature 64 (0.002869) AST_mean
# 141. feature 183 (0.002826) Weight_VAR_skew
# 142. feature 98 (0.002824) Na_skew
# 143. feature 29 (0.002546) SaO2_mean
# 144. feature 67 (0.002542) AST_min
# 145. feature 142 (0.002536) ALT_min
# 146. feature 141 (0.002500) ALT_max
# 147. feature 139 (0.002452) ALT_mean
# 148. feature 76 (0.002134) RespRate_max
# 149. feature 186 (0.001982) Gender_first
# 150. feature 77 (0.001886) RespRate_min
# 151. feature 138 (0.001795) Lactate_skew
# 152. feature 87 (0.001782) FiO2_min
# 153. feature 104 (0.001754) TroponinT_mean
# 154. feature 65 (0.001749) AST_std
# 155. feature 30 (0.001749) SaO2_std
# 156. feature 106 (0.001719) TroponinT_max
# 157. feature 100 (0.001719) Bilirubin_std
# 158. feature 33 (0.001588) SaO2_skew
# 159. feature 32 (0.001503) SaO2_min
# 160. feature 50 (0.001495) ALP_std
# 161. feature 86 (0.001408) FiO2_max
# 162. feature 107 (0.001346) TroponinT_min
# 163. feature 140 (0.001326) ALT_std
# 164. feature 105 (0.001028) TroponinT_std
# 165. feature 31 (0.000771) SaO2_max
# 166. feature 2 (0.000713) TroponinI_max
# 167. feature 0 (0.000689) TroponinI_mean
# 168. feature 3 (0.000656) TroponinI_min
# 169. feature 170 (0.000651) Albumin_std
# 170. feature 185 (0.000613) Age_first
# 171. feature 103 (0.000488) Bilirubin_skew
# 172. feature 53 (0.000482) ALP_skew
# 173. feature 68 (0.000478) AST_skew
# 174. feature 108 (0.000459) TroponinT_skew
# 175. feature 143 (0.000445) ALT_skew
# 176. feature 1 (0.000328) TroponinI_std
# 177. feature 20 (0.000212) Cholesterol_mean
# 178. feature 23 (0.000183) Cholesterol_min
# 179. feature 22 (0.000158) Cholesterol_max
# 180. feature 173 (0.000108) Albumin_skew
# 181. feature 4 (0.000009) TroponinI_skew
# 182. feature 21 (0.000000) Cholesterol_std
# 183. feature 11 (0.000000) MechVent_std
# 184. feature 12 (0.000000) MechVent_max
# 185. feature 47 (0.000000) Urine_min
# 186. feature 13 (0.000000) MechVent_min
# 187. feature 14 (0.000000) MechVent_skew
# 188. feature 10 (0.000000) MechVent_mean

# %% [markdown]
# ## Logistic  regression - Standard Scaler

# %%
# --- scaling Data ---
feature_cols = [col for col in df_a.columns if col != 'RecordID_first']

scaler = StandardScaler()
scaler.fit(df_a[feature_cols])

df_a_scaled = pd.DataFrame(scaler.transform(df_a[feature_cols]), columns=feature_cols)
df_b_scaled = pd.DataFrame(scaler.transform(df_b[feature_cols]), columns=feature_cols)
df_c_scaled = pd.DataFrame(scaler.transform(df_c[feature_cols]), columns=feature_cols)

# %%
np.logspace(-3,3, 7)
# Out:
# array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])

# %%
# --- Grid Search for Best Regularization ---
# C = inverse of regularization strength, smaller values => stronger regularization

param_grid = {'C': np.logspace(-3, 3, 7)}
grid = GridSearchCV(LogisticRegression(max_iter=600, class_weight='balanced'),
                    param_grid, cv=5, scoring='roc_auc', n_jobs=-1)
grid.fit(df_a_scaled, outcomes_a['In-hospital_death'])

best_log_reg = grid.best_estimator_
print("Best C:", grid.best_params_['C'])
# Out:
# Best C: 0.001

# %%
# --- Prediction on Test Set ---
evaluate_model(best_log_reg, df_c_scaled, outcomes_c['In-hospital_death'], title_info=f'Best Logistic Regression Model : {grid.best_estimator_}')
# Out:
# ROC AUC Score: 0.8208
# Average Precision Score: 0.4407
# (0.8207651011750573, 0.44065365481669677)

# %%
# model = best log reg but with no class weight
best_log_reg_no_weight = LogisticRegression(max_iter=600, C=grid.best_params_['C'])
best_log_reg_no_weight.fit(df_a_scaled, outcomes_a['In-hospital_death'])

evaluate_model(best_log_reg_no_weight, df_c_scaled, outcomes_c['In-hospital_death'], title_info=f'Best Logistic Regression Model without Class Weight : {best_log_reg_no_weight}')
# Out:
# ROC AUC Score: 0.8331
# Average Precision Score: 0.4669
# (0.8331123374754414, 0.4668912758594793)

# %% [markdown]
# ## Logistic  regression - MinMax scaler

# %%
# --- scaling Data ---
feature_cols = [col for col in df_a.columns if col != 'RecordID_first']

scaler = MinMaxScaler()
scaler.fit(df_a[feature_cols])

df_a_scaled = pd.DataFrame(scaler.transform(df_a[feature_cols]), columns=feature_cols)
df_b_scaled = pd.DataFrame(scaler.transform(df_b[feature_cols]), columns=feature_cols)
df_c_scaled = pd.DataFrame(scaler.transform(df_c[feature_cols]), columns=feature_cols)

np.logspace(-3,3, 7)

# --- Grid Search for Best Regularization ---
# C = inverse of regularization strength, smaller values => stronger regularization

param_grid = {'C': np.logspace(-3, 3, 7)}
grid = GridSearchCV(LogisticRegression(max_iter=600, class_weight='balanced'),
                    param_grid, cv=5, scoring='roc_auc', n_jobs=-1)
grid.fit(df_a_scaled, outcomes_a['In-hospital_death'])

best_log_reg = grid.best_estimator_
print("Best C:", grid.best_params_['C'])


# --- Prediction on Test Set ---
evaluate_model(best_log_reg, df_c_scaled, outcomes_c['In-hospital_death'], title_info=f'Best Logistic Regression Model : {grid.best_estimator_}')
# model = best log reg but with no class weight
best_log_reg_no_weight = LogisticRegression(max_iter=600, C=grid.best_params_['C'])
best_log_reg_no_weight.fit(df_a_scaled, outcomes_a['In-hospital_death'])

evaluate_model(best_log_reg_no_weight, df_c_scaled, outcomes_c['In-hospital_death'], title_info=f'Best Logistic Regression Model without Class Weight : {best_log_reg_no_weight}')
# Out:
# Best C: 0.1
# ROC AUC Score: 0.8287
# Average Precision Score: 0.4606
# ROC AUC Score: 0.8331
# Average Precision Score: 0.4669
# (0.8331123374754414, 0.4668912758594793)
